# %% [markdown]
# # **Import Library**

# %%
import io
import re 
import unicodedata
import numpy as np
import pandas as pd
import matplotlib as plt
from typing import Optional

# %% [markdown]
# # **Load Dataset**

# %%
file_path = "datasets/data_inovasi.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#    No                                      Judul Inovasi                Pemda  \
# 0   1  POP SURGA (Penghantaran Obat Pasien Sumberglagah)  Provinsi Jawa Timur
# 1   2                 PHEC (Pre Hospital Emergency Care)  Provinsi Jawa Timur
# 2   3                   Naskah Dinas Elektronik (NADINE)  Provinsi Jawa Timur
# 3   4  PERMATA ( Pertanian Ramah Lingkungan menuju Ma...  Provinsi Jawa Timur
# 4   5                                            SIGALON  Provinsi Jawa Timur
#
#                                            Admin OPD      Inisiator  \
# 0  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...  Kepala Daerah
# 1  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...            OPD
# 2  Badan Koordinasi Wilayah Pamekasan Provinsi Ja...            OPD
# 3  Dinas Pertanian dan Ketahanan Pangan (jatimpro...            OPD
# 4  Dinas Kesehatan UPT. RS Mata Masyarakat (jatim...            OPD
#
#                 Nama Inisiator  \
# 0  drg. SHINTA SAWITRI, M.Kes
# 1  drg. SHINTA SAWITRI, M.Kes
# 2     Dra. SUFI AGUSTINI, M.Si
# 3                            -
# 4                            -
#
#                                       Bentuk Inovasi        Jenis  \
# 0                           Inovasi pelayanan publik      Digital
# 1                           Inovasi pelayanan publik  Non Digital
# 2            Inovasi tata kelola pemerintahan daerah    Teknologi
# 3  Inovasi Daerah lainnya sesuai dengan Urusan Pe...      Digital
# 4                           Inovasi pelayanan publik      Digital
#
#                                           Asta Cipta Urusan Utama  \
# 0  Memperkuat pembangunan sumber daya manusia (SD...    kesehatan
# 1  Memperkuat pembangunan sumber daya manusia (SD...   pendidikan
# 2  Memperkuat reformasi politik, hukum, dan birok...    kearsipan
# 3                                                  -    pertanian
# 4                                                  -    kesehatan
#
#                           Urusan lain yang beririsan  Kematangan  \
# 0                  pekerjaan umum dan penataan ruang        85.0
# 1                                          kesehatan        92.0
# 2  Fungsi Penunjang lainnya sesuai dengan ketentu...       110.0
# 3                                                NaN        60.0
# 4                                                NaN        52.0
#
#   Tahapan Inovasi Tanggal Input Tanggal Penerapan Tanggal Pengembangan  \
# 0       Penerapan    22-07-2022        29-11-2023                    -
# 1       Penerapan    22-07-2022        24-06-2023                    -
# 2       Penerapan    20-06-2023        31-12-2024           31-12-2024
# 3        Uji Coba    26-06-2023        25-09-2023                    -
# 4       Penerapan    10-07-2023        10-07-2023                    -
#
#                                 Koordinat      Video  \
# 0   -7.60739065953564, 112.54078722662341        Ada
# 1    -7.6073109183015, 112.54072288029913        Ada
# 2  -7.158553824257441, 113.48272568540575        Ada
# 3                                     NaN  Tidak Ada
# 4                                     NaN        Ada
#
#                                           Link Video
# 0        https://www.youtube.com/watch?v=o_TedznOu3U
# 1                       https://youtu.be/TJaII4_0UkI
# 2  https://drive.google.com/file/d/192dhJGWtC4lDc...
# 3                                                  -
# 4  https://drive.google.com/file/d/1JKCIqN4TRVL-O...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   No                          679 non-null    int64
#  1   Judul Inovasi               679 non-null    object
#  2   Pemda                       679 non-null    object
#  3   Admin OPD                   679 non-null    object
#  4   Inisiator                   679 non-null    object
#  5   Nama Inisiator              679 non-null    object
#  6   Bentuk Inovasi              679 non-null    object
#  7   Jenis                       679 non-null    object
#  8   Asta Cipta                  679 non-null    object
#  9   Urusan Utama                679 non-null    object
#  10  Urusan lain yang beririsan  463 non-null    object
#  11  Kematangan                  679 non-null    float64
#  12  Tahapan Inovasi             679 non-null    object
#  13  Tanggal Input               679 non-null    object
#  14  Tanggal Penerapan           679 non-null    object
#  15  Tanggal Pengembangan        679 non-null    object
#  16  Koordinat                   587 non-null    object
#  17  Video                       679 non-null    object
#  18  Link Video                  679 non-null    object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 100.9+ KB

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
# columns that have null values
null_columns = df.isnull().sum()
null_columns[null_columns > 0]
# Out:
# Urusan lain yang beririsan    216
# Koordinat                      92
# dtype: int64

# %%
# Cek nilai "-"
dash_count = (df == "-").sum()
dash_count[dash_count > 0].sort_values(ascending=False)
# Out:
# Tanggal Pengembangan    294
# Link Video              108
# Asta Cipta               92
# Nama Inisiator           10
# dtype: int64

# %%
# check uniqe value
unique_values = {col: df[col].nunique() for col in df.columns}
unique_values
# Out:
# {'No': 679,
#  'Judul Inovasi': 664,
#  'Pemda': 1,
#  'Admin OPD': 292,
#  'Inisiator': 4,
#  'Nama Inisiator': 552,
#  'Bentuk Inovasi': 3,
#  'Jenis': 3,
#  'Asta Cipta': 9,
#  'Urusan Utama': 31,
#  'Urusan lain yang beririsan': 132,
#  'Kematangan': 89,
#  'Tahapan Inovasi': 3,
#  'Tanggal Input': 80,
#  'Tanggal Penerapan': 378,
#  'Tanggal Pengembangan': 243,
#  'Koordinat': 418,
#  'Video': 2,
#  'Link Video': 569}

# %%
# Unique values for key categorical columns
categorical_cols = [
    "Bentuk Inovasi",
    "Jenis",
    "Tahapan Inovasi",
    "Inisiator",
    "Asta Cipta",
    "Urusan Utama",
    "Urusan lain yang beririsan"
]

for col in categorical_cols:
    print(f"\nDistribusi {col}:")
    temp = df[col].value_counts().reset_index()
    temp.columns = [col, "Jumlah"]
    print(temp)
# Out:
# Distribusi Bentuk Inovasi:
#                                       Bentuk Inovasi  Jumlah
# 0                           Inovasi pelayanan publik     444
# 1  Inovasi Daerah lainnya sesuai dengan Urusan Pe...     185
# 2            Inovasi tata kelola pemerintahan daerah      50
#
# Distribusi Jenis:
#          Jenis  Jumlah
# 0  Non Digital     346
# 1      Digital     234
# 2    Teknologi      99
#
# Distribusi Tahapan Inovasi:
#   Tahapan Inovasi  Jumlah
# 0       Penerapan     648
# 1       Inisiatif      22
# 2        Uji Coba       9
#
# Distribusi Inisiator:
#        Inisiator  Jumlah
# 0            ASN     362
# 1            OPD     226
# 2  Kepala Daerah      49
# 3     Masyarakat      42
#
# Distribusi Asta Cipta:
#                                           Asta Cipta  Jumlah
# 0  Memperkuat pembangunan sumber daya manusia (SD...     400
# 1                                                  -      92
# 2  Meningkatkan lapangan kerja yang berkualitas, ...      62
# 3  Memperkuat penyelarasan kehidupan yang harmoni...      39
# 4  Memperkuat reformasi politik, hukum, dan birok...      35
# 5  Memantapkan sistem pertahanan keamanan negara ...      23
# 6  Membangun dari desa dan dari bawah untuk pemer...      13
# 7  Melanjutkan hilirisasi dan industrialisasi unt...      10
# 8  Memperkokoh ideologi Pancasila, demokrasi, dan...       5
#
# Distribusi Urusan Utama:
#                                          Urusan Utama  Jumlah
# 0                                          pendidikan     381
# 1                                           kesehatan     101
# 2                                              sosial      23
# 3   Fungsi Penunjang lainnya sesuai dengan ketentu...      15
# 4                 koperasi, usaha kecil, dan menengah      14
# 5                                              pangan      13
# 6                   pekerjaan umum dan penataan ruang      12
# 7                                         perhubungan      11
# 8                          komunikasi dan informatika       9
# 9                              kelautan dan perikanan       9
# 10  ketenteraman, ketertiban umum, dan pelindungan...       8
# 11                                       tenaga kerja       8
# 12                                   lingkungan hidup       8
# 13                                          pertanian       8
# 14                                         kebudayaan       7
# 15                           kepemudaan dan olah raga       7
# 16                                          kearsipan       6
# 17                        Penelitian dan Pengembangan       5
# 18                           Pendidikan dan Pelatihan       4
# 19                                        Kepegawaian       4
# 20                   pemberdayaan masyarakat dan Desa       4
# 21                                    penanaman modal       3
# 22                                           Keuangan       3
# 23                     energi dan sumber daya mineral       3
# 24        pemberdayaan perempuan dan pelindungan anak       3
# 25                                        Perencanaan       2
# 26                                        perdagangan       2
# 27                                         pariwisata       2
# 28            perumahan rakyat dan kawasan permukiman       2
# 29                                       perpustakaan       1
# 30     administrasi kependudukan dan pencatatan sipil       1
#
# Distribusi Urusan lain yang beririsan:
#                             Urusan lain yang beririsan  Jumlah
# 0                             Pendidikan dan Pelatihan      95
# 1    Fungsi Penunjang lainnya sesuai dengan ketentu...      32
# 2                                     lingkungan hidup      29
# 3                           komunikasi dan informatika      28
# 4                                               sosial      17
# ..                                                 ...     ...
# 127  kesehatan,pangan,lingkungan hidup,koperasi, us...       1
# 128  kesehatan,pangan,lingkungan hidup,pemberdayaan...       1
# 129  pemberdayaan masyarakat dan Desa,kebudayaan,pa...       1
# 130  kesehatan,pemberdayaan perempuan dan pelindung...       1
# 131                  pangan,lingkungan hidup,pertanian       1
#
# [132 rows x 2 columns]

# %%
# df["Tahun"] = pd.to_datetime(df["Tanggal Penerapan"], errors="coerce").dt.year
# distribusi = (
#     df
#     .groupby(["Tahun", "Jenis"])
#     .size()
#     .reset_index(name="jumlah")
# )

# print(distribusi)

# %%
print("Jumlah data duplikat:", df.duplicated(keep=False).sum())
# Out:
# Jumlah data duplikat: 0

# %%
# Check data Inovasi terduplikat
df_check = df.copy()
df_check["judul_raw"] = df_check["Judul Inovasi"].astype(str)

def text_normalize(text):
    text = str(text)
    # 1. Unicode normalize (hilangkan karakter aneh tersembunyi)
    text = unicodedata.normalize("NFKD", text)
    # 2. Lowercase
    text = text.lower()
    # 3. Samakan pemisah jadi spasi
    text = re.sub(r"[-_/]", " ", text)
    # 4. Hapus semua simbol & tanda baca → ganti spasi (BIAR KATA GA NEMPEL)
    text = re.sub(r"[^a-z0-9\s]", " ", text)
    # 5. Rapikan spasi berlebih
    text = re.sub(r"\s+", " ", text).strip()
    # 6. Hapus kata umum (stopwords) — pakai word boundary biar aman
    stopwords = ["aplikasi", "sistem", "program", "inovasi", "digital", "berbasis"]
    pattern = r"\b(" + "|".join(stopwords) + r")\b"
    text = re.sub(pattern, " ", text)

    text = re.sub(r"\s+", " ", text).strip()
    
    return text

df_check["judul_super_norm"] = df_check["judul_raw"].apply(text_normalize)
dup_group = (
    df_check
    .groupby("judul_super_norm")
    .size()
    .reset_index(name="jumlah")
    .query("jumlah > 1")
)

print("Jumlah judul yang terduplikat:", len(dup_group))
dup_norm = df_check[df_check.duplicated(subset=["judul_super_norm"], keep=False)]

columns = [
    "judul_raw",
    "judul_super_norm",
    "Admin OPD",
    "Inisiator",
    "Nama Inisiator",
    "Jenis",
    "Kematangan",
    "Tahapan Inovasi",
    "Tanggal Input",
    "Tanggal Penerapan",
    "Tanggal Pengembangan"
]

df_duplicate = (
    dup_norm[columns]
    .sort_values(by=["judul_super_norm", "Admin OPD"])
    .reset_index(drop=True)
)

df_duplicate
# Out:
# Jumlah judul yang terduplikat: 25
#                                             judul_raw  \
# 0                                        BATA MERDEKA
# 1                                       BATA MERDEKA
# 2        "BES-Q"(BERSIH ENTREPRENEUR SEHAT DAN QOLBU)
# 3       "BES-Q" (BERSIH ENTREPRENEUR SEHAT DAN QOLBU)
# 4                                        DAKSA BUDAYA
# 5                                        DAKSA BUDAYA
# 6   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 7   DIGDAYA: Digitalisasi untuk Mewujudkan Kedisip...
# 8   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 9   ‘E-KOMITE’ SISTEM MONITORING PELAYANAN PARTISI...
# 10  “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 11  “E-PKL (Elektronik Praktik Kerja Lapangan)” SM...
# 12                                     GALERY DIGITAL
# 13                                     GALERY DIGITAL
# 14  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 15  GERAKAN PENGUATAN LITERASI SEKOLAH BERBASIS DI...
# 16  JEGEG (Jaringan E-Promosi Gaungkan Generasi Ge...
# 17  JEGEG ( Jaringan E-Promosi Gaungkan Generasi G...
# 18                Program KASIKU ( Alikasi KU-Belajar
# 19                Program KASIKU ( Alikasi KU-Belajar
# 20  Legen Tuban (LitErasi, GENeralisasi, dan Tekno...
# 21  ”LEGEN TUBAN” (LitErasi, GENeralisasi, dan Tek...
# 22  PEMBUATAN  TABALIS UNTUK MENINGKATKAN KETERAMP...
# 23  Pembuatan Tabalis Untuk Meningkatkan Keterampi...
# 24  PRODUK OROK- OROK MENUJU MASYARAKAT INKLUSIF D...
# 25  PRODUK OROK-OROK MENUJU MASYARAKAT INKLUSIF DI...
# 26                      PUAS (PULANG DENGAN SENYUMAN)
# 27                    PUAS ( Pulang Dengan Senyuman )
# 28                                       PUSPA LITERA
# 29                                       PUSPA LITERA
# 30  SAKA GURU LITERASI (SATU KARYA GURU SATU LITER...
# 31  ” SAKA GURU LITERASI” (SATU KARYA GURU SATU LI...
# 32                          SEKOLAH SAK NGAJINE (SSN)
# 33                          SEKOLAH SAK NGAJINE (SSN)
# 34               SERGAP - Serangan Gabungan Pembinaan
# 35               SERGAP - Serangan Gabungan Pembinaan
# 36       SI-BECIK (Sekolahku Cantik Berhias Ecobrick)
# 37       SI_BECIK (Sekolahku Cantik Berhias Ecobrick)
# 38                                      SIJAWARA PLUS
# 39                                      SIJAWARA PLUS
# 40  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 41  SIPPS 215 (SISTEM INFORMASI POIN PELANGGARAN S...
# 42  SIPPS 215 (Sistem Informasi Poin Pelanggaran S...
# 43                                TAMAN PADUKA SANGRA
# 44                                TAMAN PADUKA SANGRA
# 45                                      TARUNA BUDAYA
# 46                                      TARUNA BUDAYA
# 47  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 48  TOPCER ‘TEKNOLOGI EMPON CHOPPER’ SOLUSI CERDAS...
# 49                                            UMISARI
# 50                                            UMISARI
#
#                                      judul_super_norm  \
# 0                                        bata merdeka
# 1                                        bata merdeka
# 2           bes q bersih entrepreneur sehat dan qolbu
# 3           bes q bersih entrepreneur sehat dan qolbu
# 4                                        daksa budaya
# 5                                        daksa budaya
# 6   digdaya digitalisasi untuk mewujudkan kedisipl...
# 7   digdaya digitalisasi untuk mewujudkan kedisipl...
# 8   e komite monitoring pelayanan partisipasi sumb...
# 9   e komite monitoring pelayanan partisipasi sumb...
# 10  e pkl elektronik praktik kerja lapangan smkn 1...
# 11  e pkl elektronik praktik kerja lapangan smkn 1...
# 12                                             galery
# 13                                             galery
# 14                 gerakan penguatan literasi sekolah
# 15                 gerakan penguatan literasi sekolah
# 16  jegeg jaringan e promosi gaungkan generasi gem...
# 17  jegeg jaringan e promosi gaungkan generasi gem...
# 18                          kasiku alikasi ku belajar
# 19                          kasiku alikasi ku belajar
# 20  legen tuban literasi generalisasi dan teknolog...
# 21  legen tuban literasi generalisasi dan teknolog...
# 22  pembuatan tabalis untuk meningkatkan keterampi...
# 23  pembuatan tabalis untuk meningkatkan keterampi...
# 24  produk orok orok menuju masyarakat inklusif di...
# 25  produk orok orok menuju masyarakat inklusif di...
# 26                        puas pulang dengan senyuman
# 27                        puas pulang dengan senyuman
# 28                                       puspa litera
# 29                                       puspa litera
# 30   saka guru literasi satu karya guru satu literasi
# 31   saka guru literasi satu karya guru satu literasi
# 32                            sekolah sak ngajine ssn
# 33                            sekolah sak ngajine ssn
# 34                 sergap serangan gabungan pembinaan
# 35                 sergap serangan gabungan pembinaan
# 36         si becik sekolahku cantik berhias ecobrick
# 37         si becik sekolahku cantik berhias ecobrick
# 38                                      sijawara plus
# 39                                      sijawara plus
# 40  sipps 215 informasi poin pelanggaran siswa smk...
# 41  sipps 215 informasi poin pelanggaran siswa smk...
# 42  sipps 215 informasi poin pelanggaran siswa smk...
# 43                                taman paduka sangra
# 44                                taman paduka sangra
# 45                                      taruna budaya
# 46                                      taruna budaya
# 47  topcer teknologi empon chopper solusi cerdas p...
# 48  topcer teknologi empon chopper solusi cerdas p...
# 49                                            umisari
# 50                                            umisari
#
#                                             Admin OPD   Inisiator  \
# 0      SMA Negeri 1 Jombang (iga2024.sma.n.1.jombang)         ASN
# 1      SMA Negeri 1 Jombang (iga2024.sma.n.1.jombang)         OPD
# 2    SMAN 1 JENANGAN, PONOROGO  (jatimprov.dispend...         OPD
# 3           SMAN 1 JENANGAN (iga2024.sman.1.jenangan)         OPD
# 4   Dinas Kebudayaan dan Pariwisata Provinsi Jawa ...         OPD
# 5      admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
# 6   SMAN 2 PONOROGO  (jatimprov.dispendik.sman2pon...         ASN
# 7           SMAN 2 PONOROGO (iga2024.sman.2.ponorogo)         ASN
# 8   SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 9   SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 10          Smkn 12 surabaya (iga2025.smkn12surabaya)         ASN
# 11          Smkn 12 surabaya (iga2025.smkn12surabaya)         ASN
# 12  SMPLB YPABK MUNCAR BANYUWANGI (jatimprov.dispe...  Masyarakat
# 13  SMPLB YPABK MUNCAR BANYUWANGI (jatimprov.dispe...  Masyarakat
# 14            SMAN 3 MAGETAN (iga2024.smkn.3.magetan)         ASN
# 15            SMAN 3 MAGETAN (iga2024.smkn.3.magetan)         ASN
# 16           SMAN 1 BADEGAN (iga2024.sman.1.badengan)         ASN
# 17  SMAN 1 BADEGAN, KAB. PONOROGO  (jatimprov.disp...         ASN
# 18      SMAN 1 SRONO (jatimprov.dispendik.sman1srono)         ASN
# 19      SMAN 1 SRONO (jatimprov.dispendik.sman1srono)         ASN
# 20  SMK NEGERI RENGEL TUBAN (iga2024.smkn.rengel.t...         ASN
# 21   SMKN 1 Rengel Tuban (iga2025.smkn1.rengel.tuban)         ASN
# 22  SLB NEGERI 1 SAMBIROTO NGAWI (iga2024.slbn1.sa...  Masyarakat
# 23  SLB NEGERI 1 SAMBIROTO NGAWI (iga2024.slbn1.sa...  Masyarakat
# 24         SLBN 1 KOTA BLITAR (iga2024.slbn.1.blitar)         ASN
# 25         SLBN 1 KOTA BLITAR (iga2024.slbn.1.blitar)         ASN
# 26  Rumah Sakit Umum Daerah Dr. Soedono Madiun (ja...         OPD
# 27     admin.jawa.timur (iga2025.provinsi.jawa.timur)         ASN
# 28  SMAN 2 PONOROGO  (jatimprov.dispendik.sman2pon...         ASN
# 29          SMAN 2 PONOROGO (iga2024.sman.2.ponorogo)         ASN
# 30  SMKN 1 PONOROGO  (jatimprov.dispendik.smkn1pon...         ASN
# 31          SMKN 1 PONOROGO (iga2024.smkn.1.ponorogo)         ASN
# 32         SLBN 2 KOTA BLITAR (iga2024.slbn.2.blitar)         ASN
# 33         SLBN 2 KOTA BLITAR (iga2024.slbn.2.blitar)         ASN
# 34  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 35  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 36  SMAN 1 Kunir  Lumajang (iga2024.sman.1.kurir.l...         ASN
# 37  SMAN 1 Kunir  Lumajang (iga2024.sman.1.kurir.l...         ASN
# 38  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 39  Dinas Koperasi, Usaha Kecil dan Menengah Provi...         OPD
# 40  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 41  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 42  SMK NEGERI 1 WATULIMO TRENGGALEK (iga2024.smkn...         ASN
# 43  SMAN 1 NGRAMBE (jatimprov.dispendik.sman1ngrambe)         ASN
# 44  SMAN 1 NGRAMBE (jatimprov.dispendik.sman1ngrambe)         ASN
# 45  Dinas Kebudayaan dan Pariwisata Provinsi Jawa ...         OPD
# 46     admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
# 47  SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 48  SMK NEGERI 1 KARE, KAB MADIUN (jatimprov.dispe...         ASN
# 49  Dinas Energi dan Sumber Daya Mineral Provinsi ...         OPD
# 50     admin.jawa.timur (iga2025.provinsi.jawa.timur)         OPD
#
#                                        Nama Inisiator        Jenis  \
# 0                        ZAGLUL RIJAL PASHA, S.Pd DKK  Non Digital
# 1                     ZAGHLUL RIJAL PHASA, S. Pd. DKK  Non Digital
# 2                         Titik Ruwaidah, S.Pd.,M.Pd.  Non Digital
# 3                        Titik Ruwaidah, S.Pd., M.Pd.  Non Digital
# 4                         Evy Afianasari, S.T., M.M.A      Digital
# 5                            Evy Afianasari, S.T, MMA      Digital
# 6                            Zanwar Sugiartoko, S.Kom      Digital
# 7                            Zanwar Sugiartoko, S.Kom      Digital
# 8                                                   -      Digital
# 9                            SEPTA KRISDIYANTO, M.Pd.      Digital
# 10                               Cone Kustarto Arifin      Digital
# 11                               Cone Kustarto Arifin      Digital
# 12                       LATU METHA MARYA MAHARDIKA P    Teknologi
# 13                       LATU METHA MARYA MAHARDIKA P      Digital
# 14                            Drs. HERY SUBAGYO, M.Pd      Digital
# 15                           Dra. RIFUL HAMIDAH, M.Pd      Digital
# 16                          Toha Mahsun, S.Pd, M.Pd.I      Digital
# 17                          Toha Mahsun, S.Pd, M.Pd.I      Digital
# 18                                             Hadiri      Digital
# 19                                             Hadiri      Digital
# 20                   TRI ERNI HUDAYAH, S. Pd., M. Pd.      Digital
# 21  TRI ERNI HUDAYAH, S.Pd., M.Pd., dan JOKO SUNTH...      Digital
# 22                       SLB NEGERI 1 SAMBIROTO NGAWI  Non Digital
# 23                       SLB Negeri 1 Sambiroto Ngawi  Non Digital
# 24                         ANA ALIYATUL HIMMAH, S. Pd  Non Digital
# 25                         Ana Aliyatul Himmah, S. Pd  Non Digital
# 26                              Khomsatun, S.Kep., Ns      Digital
# 27               dr. TAUHID ISLAMY, Sp.OG, Subsp.K.Fm      Digital
# 28                   David Agung Prasetiyoko, S.Pd.I.  Non Digital
# 29                     David Agung Prasetyoko, S.Pd.I  Non Digital
# 30                                    SURYANTO, S.Pd.  Non Digital
# 31                               KATENAN, S.Pd.M.MPd.  Non Digital
# 32                                      KHOIRUN NISAK  Non Digital
# 33                                KHOIRUN NISAK, S.Pd  Non Digital
# 34                Dr. ENDY ALIM ABDI NUSA S.IP., M.M.      Digital
# 35                Dr. ENDY ALIM ABDI NUSA S.IP., M.M.    Teknologi
# 36                                      Lina Larasati  Non Digital
# 37                                      Lina Larasati  Non Digital
# 38                 Dr. Endy Alim Abdi Nusa, S.IP., MM      Digital
# 39                 Dr. Endy Alim Abdi Nusa, S.IP., MM    Teknologi
# 40  Dr. SANTIKA, S.Pi., M.Si dan WAHYU SETYO LAKSO...      Digital
# 41  Dr. SANTIKA, S.Pi., M.Si dan WAHYU SETYO LAKSO...      Digital
# 42                         WAHYU SETYO LAKSONO, S.Pd.      Digital
# 43                       Alfian Perdhana Putra, S.Pd.      Digital
# 44                       Alfian Perdhana Putra, S.Pd.  Non Digital
# 45                        Evy Afianasari, S.T., M.M.A  Non Digital
# 46                           Evy Afianasari, S.T, MMA  Non Digital
# 47                       ANIK AMBARWATI, S.Pd., M.Si.  Non Digital
# 48                       ANIK AMBARWATI, S.Pd., M.Si.  Non Digital
# 49                                 Putri Setianingsih  Non Digital
# 50                 Dr. NURKHOLIS S.Sos.,Msi,CIPA,CIHM      Digital
#
#     Kematangan Tahapan Inovasi Tanggal Input Tanggal Penerapan  \
# 0          0.0       Penerapan    30-07-2025        01-11-2024
# 1        101.0       Penerapan    01-08-2025        06-08-2024
# 2         96.0       Penerapan    26-07-2024        09-02-2024
# 3         92.0       Penerapan    31-07-2024        03-03-2023
# 4        111.0       Penerapan    20-08-2025        04-03-2024
# 5          9.0       Penerapan    19-08-2025        02-01-2023
# 6        107.0       Penerapan    29-07-2025        15-07-2024
# 7         99.0       Penerapan    05-08-2024        15-07-2024
# 8          0.0       Penerapan    15-07-2023        27-09-2023
# 9         99.0       Penerapan    25-07-2024        27-09-2023
# 10         0.0       Penerapan    24-07-2025        02-01-2025
# 11        82.0       Penerapan    24-07-2025        07-10-2024
# 12        73.0       Penerapan    07-08-2024        01-06-2023
# 13        66.0       Penerapan    07-08-2024        01-06-2023
# 14       107.0       Penerapan    25-07-2024        01-03-2023
# 15       109.0       Penerapan    13-07-2025        06-05-2024
# 16       106.0       Penerapan    25-07-2024        16-01-2023
# 17       109.0       Penerapan    11-07-2025        16-01-2024
# 18         0.0       Penerapan    25-07-2024        18-07-2022
# 19        24.0       Penerapan    29-07-2024        04-07-2022
# 20        95.0       Penerapan    22-07-2024        22-04-2022
# 21       111.0       Penerapan    15-07-2025        21-04-2024
# 22       101.0       Penerapan    26-07-2024        24-08-2023
# 23        15.0       Penerapan    25-07-2025        25-08-2025
# 24       105.0       Penerapan    26-07-2024        26-05-2023
# 25        96.0       Penerapan    24-07-2025        05-06-2023
# 26       111.0       Penerapan    16-07-2025        01-10-2023
# 27       101.0       Penerapan    08-07-2024        01-03-2023
# 28       103.0       Penerapan    30-07-2025        15-07-2024
# 29        85.0       Penerapan    15-07-2025        15-07-2024
# 30       101.0       Penerapan    02-08-2024        07-07-2023
# 31        99.0       Penerapan    15-07-2025        07-07-2023
# 32        96.0       Penerapan    29-07-2024        10-07-2023
# 33       104.0       Penerapan    24-07-2025        10-07-2024
# 34        78.0       Penerapan    10-07-2025        02-01-2024
# 35        84.0       Penerapan    10-07-2025        02-01-2024
# 36       109.0       Penerapan    24-07-2024        03-02-2023
# 37       110.0       Penerapan    20-07-2025        03-02-2023
# 38        78.0       Penerapan    10-07-2025        02-01-2024
# 39        83.0       Penerapan    10-07-2025        02-01-2024
# 40       100.0       Penerapan    24-07-2024        04-09-2023
# 41        97.0       Penerapan    05-08-2024        04-09-2023
# 42       110.0       Penerapan    23-07-2025        04-09-2023
# 43        79.0       Penerapan    23-08-2025        09-12-2024
# 44        86.0       Penerapan    23-08-2025        09-12-2024
# 45       107.0       Penerapan    19-08-2025        19-01-2023
# 46         9.0       Penerapan    15-08-2025        01-01-2022
# 47         0.0       Inisiatif    25-07-2025        25-07-2025
# 48        65.0       Penerapan    06-08-2025        01-03-2024
# 49        64.0       Penerapan    08-08-2025        01-01-2024
# 50        85.0       Penerapan    17-07-2024        15-01-2021
#
#    Tanggal Pengembangan
# 0                     -
# 1                     -
# 2            26-04-2024
# 3            21-07-2023
# 4            04-03-2024
# 5            02-01-2024
# 6                     -
# 7                     -
# 8                     -
# 9            18-12-2023
# 10                    -
# 11                    -
# 12                    -
# 13                    -
# 14                    -
# 15                    -
# 16                    -
# 17           16-01-2024
# 18           02-01-2023
# 19           02-01-2023
# 20           10-07-2023
# 21           21-05-2024
# 22           10-10-2023
# 23           25-08-2025
# 24                    -
# 25           10-10-2023
# 26                    -
# 27           01-03-2023
# 28                    -
# 29                    -
# 30                    -
# 31           17-09-2023
# 32           10-07-2023
# 33           01-06-2024
# 34                    -
# 35                    -
# 36                    -
# 37                    -
# 38                    -
# 39                    -
# 40                    -
# 41                    -
# 42           02-12-2024
# 43           19-03-2025
# 44                    -
# 45           19-01-2024
# 46           12-03-2024
# 47                    -
# 48                    -
# 49           08-06-2024
# 50           11-01-2023

# %% [markdown]
# # **Preprocessing**

# %%
df_clean = df.copy()

# %%
# merapikan nama kolom (lower case)
df_clean.columns = (
    df_clean.columns
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('.', '', regex=False)
)

string_cols = df_clean.select_dtypes(include="object").columns
for col in string_cols:
    df_clean[col] = df_clean[col].str.strip()

# %%
# Standarisasi missing value ("-" diganti NaN (kecuali link_video))
for col in df_clean.columns:
    if col != "link_video":
        df_clean[col] = df_clean[col].replace("-", np.nan)

# %%
# Konversi column date
date_cols = [
    "tanggal_input",
    "tanggal_pengembangan",
    "tanggal_penerapan"
]

for col in date_cols:
    df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# Out:
# C:\Users\Dicky Zulfikar\AppData\Local\Temp\ipykernel_9160\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# C:\Users\Dicky Zulfikar\AppData\Local\Temp\ipykernel_9160\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")
# C:\Users\Dicky Zulfikar\AppData\Local\Temp\ipykernel_9160\1711946224.py:9: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")

# %%
# Penanganan kolom kategorikal null
df_clean["urusan_lain_yang_beririsan"] = (
    df_clean["urusan_lain_yang_beririsan"]
    .fillna("Tidak Ada")
)

df_clean["nama_inisiator"] = (
    df_clean["nama_inisiator"]
    .replace("-", pd.NA)
    .fillna("Tidak Disebutkan")
)

df_clean["asta_cipta"] = (
    df_clean["asta_cipta"]
    .replace("-", pd.NA)
    .fillna("Tidak Diisi")
)

# %%
# Konversi numerik column 'kematangan'
df_clean['kematangan'] = pd.to_numeric(
    df_clean['kematangan'],
    errors='coerce'
)

# hanya hapus nilai negatif
df_clean.loc[
    df_clean['kematangan'] < 0,
    'kematangan'
] = np.nan

# %%
# hapus inovasi duplikat berdasarkan nilai kematangan tertinggi
def inovasi_normalize(text):
    text = str(text)
    text = unicodedata.normalize("NFKD", text)
    text = text.lower()
    text = re.sub(r"[-_/]", " ", text)          
    text = re.sub(r"[^a-z0-9\s]", " ", text)  
    text = re.sub(r"\s+", " ", text).strip()  

    stopwords = ["aplikasi", "sistem", "program", "inovasi", "digital", "berbasis"]
    pattern = r"\b(" + "|".join(stopwords) + r")\b"
    text = re.sub(pattern, " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    return text

df_clean["judul_key"] = df_clean["judul_inovasi"].apply(inovasi_normalize)
idx = df_clean.groupby("judul_key")["kematangan"].idxmax()

df_clean = (
    df_clean.loc[idx] 
    .sort_index()      
    .drop(columns=["judul_key"])  
)

# %%
# labeling nilai kematangan
def label_kematangan(nilai):
    if pd.isna(nilai):
        return np.nan
    elif 0 <= nilai <= 44.99:
        return "Kurang Inovatif"
    elif 45 <= nilai <= 64.99:
        return "Inovatif"
    elif 65 <= nilai <= 111:
        return "Sangat Inovatif"
    else:
        return np.nan

df_clean["label_kematangan"] = df_clean["kematangan"].apply(label_kematangan)

# %%
# normalisasi koordinat (lat & lon)
def clean_coordinates(df: pd.DataFrame) -> pd.DataFrame:
    df['lat'] = np.nan
    df['lon'] = np.nan
    
    if 'koordinat' not in df.columns:
        return df

    def parse_coord(text):
        if pd.isna(text) or text == '' or text == '-':
            return np.nan, np.nan
            
        text = str(text).strip()
        match_decimal = re.search(r'(-?\d+\.\d+)[,\s]+.*?(-?\d+\.\d+)', text)
        if match_decimal:
            return float(match_decimal.group(1)), float(match_decimal.group(2))

        match_comma = re.findall(r'(-?\d+)', text)
        if len(match_comma) >= 4:
            try:
                lat = float(f"{match_comma[0]}.{match_comma[1]}")
                lon = float(f"{match_comma[2]}.{match_comma[3]}")
                if -11 <= lat <= -6 and 110 <= lon <= 116: 
                    return lat, lon
            except:
                pass
        return np.nan, np.nan

    coords = df['koordinat'].apply(parse_coord)

    df['lat'] = [c[0] for c in coords]
    df['lon'] = [c[1] for c in coords]
    df.drop(columns=['koordinat'], inplace=True)
    
    return df

df_clean = clean_coordinates(df_clean)
print(df_clean[['lat', 'lon']].info())
print("\nContoh data yang berhasil diekstrak:")
print(df_clean[['lat', 'lon']].dropna().head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 0 to 678
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     517 non-null    float64
#  1   lon     517 non-null    float64
# dtypes: float64(2)
# memory usage: 15.3 KB
# None
#
# Contoh data yang berhasil diekstrak:
#          lat         lon
# 0  -7.607391  112.540787
# 1  -7.607311  112.540723
# 2  -7.158554  113.482726
# 5  -7.325387  112.731079
# 14 -6.993797  110.420183

# %%
# title case
title_case_cols = [
    "bentuk_inovasi",
    "urusan_utama",
    "urusan_lain_yang_beririsan",
]

for col in title_case_cols:
    df_clean[col] = (
        df_clean[col]
        .astype(str)
        .str.strip()
        .replace("nan", pd.NA)   
        .str.title()
    )

# %% [markdown]
# ## Pipeline Preprocessing

# %%
def preprocessing_pipeline(df: pd.DataFrame) -> pd.DataFrame:
    df_clean = df.copy()

    # 1. Rapikan nama kolom
    df_clean.columns = (
        df_clean.columns
        .str.lower()
        .str.replace(' ', '_')
        .str.replace('.', '', regex=False)
    )

    # 2. Strip string
    string_cols = df_clean.select_dtypes(include="object").columns
    for col in string_cols:
        df_clean[col] = df_clean[col].str.strip()

    # 3. Standarisasi missing value
    for col in df_clean.columns:
        if col != "link_video":
            df_clean[col] = df_clean[col].replace("-", np.nan)

    # 4. Konversi tanggal
    date_cols = ["tanggal_input", "tanggal_pengembangan", "tanggal_penerapan"]
    for col in date_cols:
        df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")

    # 5. Penanganan kategorikal
    df_clean["urusan_lain_yang_beririsan"] = df_clean["urusan_lain_yang_beririsan"].fillna("Tidak Ada")
    df_clean["nama_inisiator"] = df_clean["nama_inisiator"].fillna("Tidak Disebutkan")
    df_clean["asta_cipta"] = df_clean["asta_cipta"].fillna("Tidak Diisi")

    # 6. Kematangan numerik
    df_clean['kematangan'] = pd.to_numeric(df_clean['kematangan'], errors='coerce')
    df_clean.loc[df_clean['kematangan'] < 0, 'kematangan'] = np.nan

    # 🔥 7. Deduplikasi Judul Inovasi
    df_clean["judul_key"] = df_clean["judul_inovasi"].apply(inovasi_normalize)

    # Ambil baris dengan kematangan tertinggi per judul
    idx = df_clean.groupby("judul_key")["kematangan"].idxmax()

    df_clean = (
        df_clean.loc[idx]
        .sort_index()
        .drop(columns=["judul_key"])
    )

    # 8. Label kematangan
    def label_kematangan(nilai):
        if pd.isna(nilai):
            return np.nan
        elif 0 <= nilai <= 44.99:
            return "Kurang Inovatif"
        elif 45 <= nilai <= 64.99:
            return "Inovatif"
        elif 65 <= nilai <= 111:
            return "Sangat Inovatif"
        else:
            return np.nan

    df_clean["label_kematangan"] = df_clean["kematangan"].apply(label_kematangan)

    # 9. Koordinat
    df_clean = clean_coordinates(df_clean)

    # 10. Title case
    title_case_cols = ["bentuk_inovasi", "urusan_utama", "urusan_lain_yang_beririsan"]
    for col in title_case_cols:
        df_clean[col] = df_clean[col].astype(str).replace("nan", pd.NA).str.title()

    return df_clean

# %%
df_clean.head()
# Out:
#    no                                      judul_inovasi                pemda  \
# 0   1  POP SURGA (Penghantaran Obat Pasien Sumberglagah)  Provinsi Jawa Timur
# 1   2                 PHEC (Pre Hospital Emergency Care)  Provinsi Jawa Timur
# 2   3                   Naskah Dinas Elektronik (NADINE)  Provinsi Jawa Timur
# 3   4  PERMATA ( Pertanian Ramah Lingkungan menuju Ma...  Provinsi Jawa Timur
# 4   5                                            SIGALON  Provinsi Jawa Timur
#
#                                            admin_opd      inisiator  \
# 0  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...  Kepala Daerah
# 1  Dinas Kesehatan UPT. RSK Sumberglagah Mojokert...            OPD
# 2  Badan Koordinasi Wilayah Pamekasan Provinsi Ja...            OPD
# 3  Dinas Pertanian dan Ketahanan Pangan (jatimpro...            OPD
# 4  Dinas Kesehatan UPT. RS Mata Masyarakat (jatim...            OPD
#
#                nama_inisiator  \
# 0  drg. SHINTA SAWITRI, M.Kes
# 1  drg. SHINTA SAWITRI, M.Kes
# 2    Dra. SUFI AGUSTINI, M.Si
# 3            Tidak Disebutkan
# 4            Tidak Disebutkan
#
#                                       bentuk_inovasi        jenis  \
# 0                           Inovasi Pelayanan Publik      Digital
# 1                           Inovasi Pelayanan Publik  Non Digital
# 2            Inovasi Tata Kelola Pemerintahan Daerah    Teknologi
# 3  Inovasi Daerah Lainnya Sesuai Dengan Urusan Pe...      Digital
# 4                           Inovasi Pelayanan Publik      Digital
#
#                                           asta_cipta urusan_utama  ...  \
# 0  Memperkuat pembangunan sumber daya manusia (SD...    Kesehatan  ...
# 1  Memperkuat pembangunan sumber daya manusia (SD...   Pendidikan  ...
# 2  Memperkuat reformasi politik, hukum, dan birok...    Kearsipan  ...
# 3                                        Tidak Diisi    Pertanian  ...
# 4                                        Tidak Diisi    Kesehatan  ...
#
#   kematangan  tahapan_inovasi tanggal_input tanggal_penerapan  \
# 0       85.0        Penerapan    2022-07-22        2023-11-29
# 1       92.0        Penerapan    2022-07-22        2023-06-24
# 2      110.0        Penerapan    2023-06-20        2024-12-31
# 3       60.0         Uji Coba    2023-06-26        2023-09-25
# 4       52.0        Penerapan    2023-07-10        2023-07-10
#
#   tanggal_pengembangan      video  \
# 0                  NaT        Ada
# 1                  NaT        Ada
# 2           2024-12-31        Ada
# 3                  NaT  Tidak Ada
# 4                  NaT        Ada
#
#                                           link_video label_kematangan  \
# 0        https://www.youtube.com/watch?v=o_TedznOu3U  Sangat Inovatif
# 1                       https://youtu.be/TJaII4_0UkI  Sangat Inovatif
# 2  https://drive.google.com/file/d/192dhJGWtC4lDc...  Sangat Inovatif
# 3                                                  -         Inovatif
# 4  https://drive.google.com/file/d/1JKCIqN4TRVL-O...         Inovatif
#
#         lat         lon
# 0 -7.607391  112.540787
# 1 -7.607311  112.540723
# 2 -7.158554  113.482726
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 21 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 0 to 678
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   no                          653 non-null    int64
#  1   judul_inovasi               653 non-null    object
#  2   pemda                       653 non-null    object
#  3   admin_opd                   653 non-null    object
#  4   inisiator                   653 non-null    object
#  5   nama_inisiator              653 non-null    object
#  6   bentuk_inovasi              653 non-null    object
#  7   jenis                       653 non-null    object
#  8   asta_cipta                  653 non-null    object
#  9   urusan_utama                653 non-null    object
#  10  urusan_lain_yang_beririsan  653 non-null    object
#  11  kematangan                  653 non-null    float64
#  12  tahapan_inovasi             653 non-null    object
#  13  tanggal_input               653 non-null    datetime64[ns]
#  14  tanggal_penerapan           653 non-null    datetime64[ns]
#  15  tanggal_pengembangan        373 non-null    datetime64[ns]
#  16  video                       653 non-null    object
#  17  link_video                  653 non-null    object
#  18  label_kematangan            653 non-null    object
#  19  lat                         517 non-null    float64
#  20  lon                         517 non-null    float64
# dtypes: datetime64[ns](3), float64(3), int64(1), object(14)
# memory usage: 112.2+ KB

# %%
df_clean.to_csv("datasets/data_inovasi_clean.csv", index=False)
